# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from metrics.scannet_eval import eval_mIoU

# %%
eval_mIoU(
    submission_dir="/home/guangda/repos/LabelMaker-Pointcept/exp/scannet200/alc_pretrain_scannet200_ft_train_newtest/result/submit_oversegmentation_refined",
    # scannet_processed_data_dir="/home/guangda/repos/LabelMaker-Pointcept/data/mix3d_preprocessed/scannet",
    scannet_processed_data_dir="/home/guangda/repos/LabelMaker-Pointcept/data/mix3d_preprocessed/scannet200",
    # labelspace="scannet",
    labelspace="scannet200",
)
# Out:
# 312it [00:07, 41.01it/s]
# (49540568,) (49540568,)
# {
#     "mIoU": 0.010854648295861875,
#     "label_mIoU": {
#         "wall": 0.3743480292669231,
#         "chair": 0.008234030788463543,
#         "floor": 0.5748835659989053,
#         "table": 0.007458263118705177,
#         "door": 0.006970708940210831,
#         "couch": 0.06769940133299018,
#         "cabinet": 0.004121553023376067,
#         "shelf": 0.0,
#         "desk": 0.00823655008653399,
#         "office chair": 0.0,
#         "bed": 0.02658322451554797,
#         "pillow": 0.026289769092072354,
#         "sink": 0.0,
#         "picture": 0.018222174101342574,
#         "window": 0.010802553442558468,
#         "toilet": 0.01804777719409151,
#         "bookshelf": 5.149175155407433e-05,
#         "monitor": 0.0,
#         "curtain": 0.00257392034537995,
#         "book": 0.0,
#         "armchair": 0.0003400331298333838,
#         "coffee table": 0.0007451607214976024,
#         "box": 0.0010881039382866424,
# ...
